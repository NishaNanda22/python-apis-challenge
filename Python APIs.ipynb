# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
coordinates = []
cities = []

lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
longs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
coordinates = zip(lats, longs)


for lat_long in lat_long:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
    cities.append(city)

len(cities)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c81bac3106fb> in <module>
#       8
#       9 for lat_long in lat_long:
# ---> 10     city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
#      11     cities.append(city)
#      12
#
# TypeError: 'zip' object is not subscriptable

# %%
coordinates = []
cities = []

lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
longs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
coordinates = zip(*[lats, longs])

#forgot to make unique list and need to unzip because python2 vs python 3 ?
for lat_long in lat_long:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
    for city not in cities
    cities.append(city)

len(cities)
# Out:
#   File "<ipython-input-15-34e2be76b6a2>", line 11
#     for city not in cities
#                ^
# SyntaxError: invalid syntax

# %%
coordinates = []
cities = []

lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
longs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
coordinates = zip(*[lats, longs])

#forgot to make unique list and need to unzip because python2 vs python 3 ?
for coordinates in coordinates:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 747

# %%
import json

# %%
print(json.loads(cities))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-db7dea9447a9> in <module>
# ----> 1 print(json.loads(cities))
#       2
#
# ~/opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
jsonStr = json.dumps(cities)

# %%
print(json.dumps(cities))
# Out:
# ["blagoyevo", "samarai", "lichinga", "albany", "bluff", "port alfred", "lebu", "sabang", "meulaboh", "katherine", "port elizabeth", "hermanus", "bathsheba", "buala", "cherskiy", "tigil", "duma", "port blair", "yangjiang", "vaini", "klaksvik", "barentsburg", "saint george", "honiara", "deputatskiy", "nanortalik", "east london", "upernavik", "atuona", "busselton", "geraldton", "rognan", "cazaje", "rikitea", "tabou", "saint-pierre", "bengkulu", "amderma", "luderitz", "broken hill", "hilo", "eganville", "ketchikan", "ramona", "meyungs", "new norfolk", "nieuwpoort", "clyde river", "kapaa", "dikson", "balimo", "castro", "ribeira grande", "gandorhun", "anadyr", "punta arenas", "asau", "salzhemmendorf", "cape town", "aflu", "podgornoye", "bonthe", "aklavik", "hasaki", "koumac", "jamestown", "provideniya", "chuy", "havelock", "becerril", "opuwo", "kailua", "olafsvik", "sistranda", "sibiti", "mujiayingzi", "kontagora", "faanui", "nikolskoye", "koryukivka", "tasiilaq", "bambous virieux", "fairb
# ...

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

city_info = []
record_count = 1

for i, city in enumerate(cities):

    city_web = url + "&q=" + city
    record_count += 1

    city_weather = requests.get(city_web).json()

    lats = city_weather_pd["Lats"]
    max_temps = city_data_pd["Max Temp"]
    humidity = city_data_pd["Humidity"]
    cloudiness = city_data_pd["Cloudiness"]
    wind_speed = city_data_pd["Wind Speed"]

    city_info.append({"City": city, 
                          "Lats": city_lat, 
                          "Max Temp": high_temp,
                          "Humidity": humidity,
                          "Cloudiness": cloudy,
                          "Wind Speed": wind_speed
                         })
              
print (city_info)
# Out:
# [{'City': 'blagoyevo', 'Lat': {'cod': 401, 'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}, 'Max Temp': {'cod': 401, 'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}, 'Humidity': {'cod': 401, 'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}, 'Cloudiness': {'cod': 401, 'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}, 'Wind Speed': {'cod': 401, 'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}}, {'City': 'samarai', 'Lat': {'cod': 401, 'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}, 'Max Temp': {'cod': 401, 'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}, 'Humidity': {'cod': 401, 'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 fo
# ...

# %%
city_weather_pd = pd.DataFrame(city_weather)

city_lat = city_weather_pd
high_temp = city_weather_pd
humidity = city_weather_pd
cloudy = city_weather_pd[
wind_speed = city_weather_pd

city_weather_pd.to_csv(output_data_file, index_label="city_id")

city_weather_pd.head()
# Out:
#   File "<ipython-input-1-cfc4d7d1fc0e>", line 7
#     wind_speed = city_weather_pd
#                ^
# SyntaxError: invalid syntax
